# %%
# We used google colab to train the models and google drive to store the models. This was the code we used:

from google.colab import drive
import os

# connect to drive
drive.mount('/content/drive')


project_path = '/content/drive/MyDrive/NLPGroup29'

try:
    os.chdir(project_path)
    print(f"Erfolgreich in Ordner gewechselt: {os.getcwd()}")
except FileNotFoundError:
    print("Fehler: Ordner nicht gefunden! Bitte Pfad prüfen.")

print("Installiere Bibliotheken...")
# !pip install -r requirements.txt
# Out:
# Mounted at /content/drive
# Erfolgreich in Ordner gewechselt: /content/drive/MyDrive/NLPGroup29
# Installiere Bibliotheken...
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 1)) (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 2)) (2.0.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (1.6.1)
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 4)) (4.0.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 5)) (3.9.1)
# Collecting contractions (from -r requirements.txt (line 6))
#   Downloading contractions-0.1.73-py2.py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 7)) (2.9.0+cu126)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 8)) (4.57.3)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 9)) (0.2.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 10)) (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 11)) (0.13.2)
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 12)) (1.9.4)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 13)) (6.17.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->-r requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->-r requirements.txt (line 1)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->-r requirements.txt (line 1)) (2025.3)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r requirements.txt (line 3)) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r requirements.txt (line 3)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->-r requirements.txt (line 3)) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets->-r requirements.txt (line 4)) (3.20.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets->-r requirements.txt (line 4)) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets->-r requirements.txt (line 4)) (0.3.8)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets->-r requirements.txt (line 4)) (2.32.4)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.12/dist-packages (from datasets->-r requirements.txt (line 4)) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets->-r requirements.txt (line 4)) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets->-r requirements.txt (line 4)) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets->-r requirements.txt (line 4)) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from datasets->-r requirements.txt (line 4)) (0.36.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from datasets->-r requirements.txt (line 4)) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets->-r requirements.txt (line 4)) (6.0.3)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk->-r requirements.txt (line 5)) (8.3.1)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk->-r requirements.txt (line 5)) (2025.11.3)
# Collecting textsearch>=0.0.21 (from contractions->-r requirements.txt (line 6))
#   Downloading textsearch-0.0.24-py2.py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 7)) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 7)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 7)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 7)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 7)) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 7)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 7)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 7)) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 7)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 7)) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 7)) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 7)) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 7)) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 7)) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 7)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 7)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 7)) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 7)) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 7)) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 7)) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch->-r requirements.txt (line 7)) (3.5.0)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers->-r requirements.txt (line 8)) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers->-r requirements.txt (line 8)) (0.7.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 10)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 10)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 10)) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 10)) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 10)) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->-r requirements.txt (line 10)) (3.2.5)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel->-r requirements.txt (line 13)) (1.8.15)
# Requirement already satisfied: ipython>=7.23.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel->-r requirements.txt (line 13)) (7.34.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.12/dist-packages (from ipykernel->-r requirements.txt (line 13)) (7.4.9)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel->-r requirements.txt (line 13)) (0.2.1)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from ipykernel->-r requirements.txt (line 13)) (1.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ipykernel->-r requirements.txt (line 13)) (5.9.5)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.12/dist-packages (from ipykernel->-r requirements.txt (line 13)) (26.2.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel->-r requirements.txt (line 13)) (6.5.1)
# Requirement already satisfied: traitlets>=5.1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel->-r requirements.txt (line 13)) (5.7.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets->-r requirements.txt (line 4)) (3.13.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets->-r requirements.txt (line 4)) (1.2.0)
# Collecting jedi>=0.16 (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 13))
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 13)) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 13)) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 13)) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 13)) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 13)) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 13)) (4.9.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel->-r requirements.txt (line 13)) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel->-r requirements.txt (line 13)) (5.9.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 1)) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets->-r requirements.txt (line 4)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets->-r requirements.txt (line 4)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets->-r requirements.txt (line 4)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets->-r requirements.txt (line 4)) (2025.11.12)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->-r requirements.txt (line 7)) (1.3.0)
# Collecting anyascii (from textsearch>=0.0.21->contractions->-r requirements.txt (line 6))
#   Downloading anyascii-0.3.3-py3-none-any.whl.metadata (1.6 kB)
# Collecting pyahocorasick (from textsearch>=0.0.21->contractions->-r requirements.txt (line 6))
#   Downloading pyahocorasick-2.3.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->-r requirements.txt (line 7)) (3.0.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->-r requirements.txt (line 4)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->-r requirements.txt (line 4)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->-r requirements.txt (line 4)) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->-r requirements.txt (line 4)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->-r requirements.txt (line 4)) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->-r requirements.txt (line 4)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets->-r requirements.txt (line 4)) (1.22.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->-r requirements.txt (line 13)) (0.8.5)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel->-r requirements.txt (line 13)) (4.5.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->-r requirements.txt (line 13)) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel->-r requirements.txt (line 13)) (0.2.14)
# Downloading contractions-0.1.73-py2.py3-none-any.whl (8.7 kB)
# Downloading textsearch-0.0.24-py2.py3-none-any.whl (7.6 kB)
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 31.3 MB/s eta 0:00:00
# Downloading anyascii-0.3.3-py3-none-any.whl (345 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.1/345.1 kB 29.6 MB/s eta 0:00:00
# Downloading pyahocorasick-2.3.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (114 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.9/114.9 kB 12.1 MB/s eta 0:00:00
# Installing collected packages: pyahocorasick, jedi, anyascii, textsearch, contractions
# Successfully installed anyascii-0.3.3 contractions-0.1.73 jedi-0.19.2 pyahocorasick-2.3.0 textsearch-0.0.24

# %%
print("Start experiment 1: Direct Clarity Training...")
# !python -m src.train_direct
# Out:
# Start experiment 1: Direct Clarity Training...
# 2025-12-24 09:01:19.315195: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766566879.335701     851 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766566879.341828     851 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1766566879.358572     851 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766566879.358624     851 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766566879.358632     851 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766566879.358636     851 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-12-24 09:01:19.363996: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# === STARTING DIRECT CLARITY TRAINING (3 Classes) ===
# spiece.model: 100% 798k/798k [00:00<00:00, 4.14MB/s]
# tokenizer.json: 100% 1.38M/1.38M [00:00<00:00, 5.41MB/s]
# config.json: 100% 760/760 [00:00<00:00, 6.25MB/s]
# --- Loading Datasets (Mode: clarity) ---
# Applying Democratic Voting Logic...
# Train size: 3448 | Test size: 308
# Clarity Class Weights: tensor([1.0925, 0.5634, 3.2285], device='cuda:0')
# loading xlnet-base-cased with 3 labels...
# pytorch_model.bin: 100% 467M/467M [00:05<00:00, 80.9MB/s]
#
# Epoch 1/15
# model.safetensors: 100% 467M/467M [00:03<00:00, 119MB/s]
#   Training Loss: 1.0150
#   >>> Evaluation Report (Direct Clarity):
#                  precision    recall  f1-score   support
#
#     Clear Reply       0.50      0.06      0.11        79
#      Ambivalent       0.71      0.88      0.79       206
# Clear Non-Reply       0.40      0.74      0.52        23
#
#        accuracy                           0.66       308
#       macro avg       0.54      0.56      0.47       308
#    weighted avg       0.63      0.66      0.59       308
#
#   [+] New Best Model (F1: 0.4709) -> Saving...
#
# Epoch 2/15
#   Training Loss: 0.8073
#   >>> Evaluation Report (Direct Clarity):
#                  precision    recall  f1-score   support
#
#     Clear Reply       0.28      0.94      0.43        79
#      Ambivalent       1.00      0.01      0.03       206
# Clear Non-Reply       0.37      0.65      0.47        23
#
#        accuracy                           0.30       308
#       macro avg       0.55      0.53      0.31       308
#    weighted avg       0.77      0.30      0.16       308
#
#
# Epoch 3/15
#   Training Loss: 0.6715
#   >>> Evaluation Report (Direct Clarity):
#                  precision    recall  f1-score   support
#
#     Clear Reply       0.41      0.48      0.44        79
#      Ambivalent       0.76      0.65      0.70       206
# Clear Non-Reply       0.42      0.74      0.54        23
#
#        accuracy                           0.61       308
#       macro avg       0.53      0.62      0.56       308
#    weighted avg       0.64      0.61      0.62       308
#
#   [+] New Best Model (F1: 0.5599) -> Saving...
#
# Epoch 4/15
#   Training Loss: 0.5212
#   >>> Evaluation Report (Direct Clarity):
#                  precision    recall  f1-score   support
#
#     Clear Reply       0.39      0.72      0.51        79
#      Ambivalent       0.84      0.51      0.64       206
# Clear Non-Reply       0.38      0.61      0.47        23
#
#        accuracy                           0.57       308
#       macro avg       0.54      0.61      0.54       308
#    weighted avg       0.69      0.57      0.59       308
#
#
# Epoch 5/15
#   Training Loss: 0.4002
#   >>> Evaluation Report (Direct Clarity):
#                  precision    recall  f1-score   support
#
#     Clear Reply       0.38      0.77      0.51        79
#      Ambivalent       0.83      0.49      0.61       206
# Clear Non-Reply       0.38      0.43      0.41        23
#
#        accuracy                           0.56       308
#       macro avg       0.53      0.56      0.51       308
#    weighted avg       0.68      0.56      0.57       308
#
#
# Epoch 6/15
#   Training Loss: 0.3189
#   >>> Evaluation Report (Direct Clarity):
#                  precision    recall  f1-score   support
#
#     Clear Reply       0.44      0.70      0.54        79
#      Ambivalent       0.81      0.63      0.71       206
# Clear Non-Reply       0.52      0.52      0.52        23
#
#        accuracy                           0.64       308
#       macro avg       0.59      0.61      0.59       308
#    weighted avg       0.69      0.64      0.65       308
#
#   [+] New Best Model (F1: 0.5884) -> Saving...
#
# Epoch 7/15
#   Training Loss: 0.2280
#   >>> Evaluation Report (Direct Clarity):
#                  precision    recall  f1-score   support
#
#     Clear Reply       0.37      0.86      0.52        79
#      Ambivalent       0.87      0.43      0.58       206
# Clear Non-Reply       0.50      0.52      0.51        23
#
#        accuracy                           0.55       308
#       macro avg       0.58      0.60      0.54       308
#    weighted avg       0.72      0.55      0.56       308
#
#
# Epoch 8/15
#   Training Loss: 0.1703
#   >>> Evaluation Report (Direct Clarity):
#                  precision    recall  f1-score   support
#
#     Clear Reply       0.45      0.75      0.56        79
#      Ambivalent       0.82      0.62      0.70       206
# Clear Non-Reply       0.57      0.57      0.57        23
#
#        accuracy                           0.65       308
#       macro avg       0.61      0.64      0.61       308
#    weighted avg       0.71      0.65      0.66       308
#
#   [+] New Best Model (F1: 0.6111) -> Saving...
#
# Epoch 9/15
#   Training Loss: 0.1235
#   >>> Evaluation Report (Direct Clarity):
#                  precision    recall  f1-score   support
#
#     Clear Reply       0.46      0.65      0.54        79
#      Ambivalent       0.81      0.65      0.72       206
# Clear Non-Reply       0.48      0.70      0.57        23
#
#        accuracy                           0.65       308
#       macro avg       0.59      0.66      0.61       308
#    weighted avg       0.70      0.65      0.66       308
#
#
# Epoch 10/15
#   Training Loss: 0.0829
#   >>> Evaluation Report (Direct Clarity):
#                  precision    recall  f1-score   support
#
#     Clear Reply       0.47      0.63      0.54        79
#      Ambivalent       0.79      0.69      0.74       206
# Clear Non-Reply       0.55      0.52      0.53        23
#
#        accuracy                           0.67       308
#       macro avg       0.60      0.62      0.60       308
#    weighted avg       0.69      0.67      0.67       308
#
#
# Epoch 11/15
#   Training Loss: 0.0545
#   >>> Evaluation Report (Direct Clarity):
#                  precision    recall  f1-score   support
#
#     Clear Reply       0.50      0.67      0.57        79
#      Ambivalent       0.81      0.71      0.76       206
# Clear Non-Reply       0.63      0.52      0.57        23
#
#        accuracy                           0.69       308
#       macro avg       0.64      0.64      0.63       308
#    weighted avg       0.71      0.69      0.70       308
#
#   [+] New Best Model (F1: 0.6330) -> Saving...
#
# Epoch 12/15
#   Training Loss: 0.0468
#   >>> Evaluation Report (Direct Clarity):
#                  precision    recall  f1-score   support
#
#     Clear Reply       0.53      0.61      0.56        79
#      Ambivalent       0.82      0.74      0.78       206
# Clear Non-Reply       0.55      0.74      0.63        23
#
#        accuracy                           0.71       308
#       macro avg       0.63      0.70      0.66       308
#    weighted avg       0.73      0.71      0.71       308
#
#   [+] New Best Model (F1: 0.6583) -> Saving...
#
# Epoch 13/15
#   Training Loss: 0.0333
#   >>> Evaluation Report (Direct Clarity):
#                  precision    recall  f1-score   support
#
#     Clear Reply       0.49      0.67      0.57        79
#      Ambivalent       0.81      0.70      0.75       206
# Clear Non-Reply       0.60      0.52      0.56        23
#
#        accuracy                           0.68       308
#       macro avg       0.63      0.63      0.63       308
#    weighted avg       0.71      0.68      0.69       308
#
#
# Epoch 14/15
#   Training Loss: 0.0254
#   >>> Evaluation Report (Direct Clarity):
#                  precision    recall  f1-score   support
#
#     Clear Reply       0.45      0.67      0.54        79
#      Ambivalent       0.79      0.66      0.72       206
# Clear Non-Reply       0.58      0.48      0.52        23
#
#        accuracy                           0.65       308
#       macro avg       0.61      0.60      0.59       308
#    weighted avg       0.69      0.65      0.66       308
#
#
# Epoch 15/15
#   Training Loss: 0.0181
#   >>> Evaluation Report (Direct Clarity):
#                  precision    recall  f1-score   support
#
#     Clear Reply       0.46      0.68      0.55        79
#      Ambivalent       0.81      0.67      0.73       206
# Clear Non-Reply       0.60      0.52      0.56        23
#
#        accuracy                           0.66       308
#       macro avg       0.62      0.63      0.61       308
#    weighted avg       0.70      0.66      0.67       308
#
#
# Done. Best Direct Clarity F1: 0.6583

# %%
print("Start Experiment 2: Hierarchical Training (k=9)...")
# !python -m src.train_hierarchical
# Out:
# Start Experiment 2: Hierarchical Training (k=9)...
# 2025-12-24 12:11:16.371527: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766578276.391780    1257 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766578276.397738    1257 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1766578276.412851    1257 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766578276.412879    1257 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766578276.412883    1257 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766578276.412886    1257 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-12-24 12:11:16.417504: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# === STARTING HIERARCHICAL TRAINING (k=9) ===
# spiece.model: 100% 798k/798k [00:00<00:00, 5.97MB/s]
# tokenizer.json: 100% 1.38M/1.38M [00:00<00:00, 6.67MB/s]
# config.json: 100% 760/760 [00:00<00:00, 5.61MB/s]
# --- Loading Datasets (Mode: evasion_9) ---
# Applying Democratic Voting Logic...
# Train size: 3448 | Test size: 308
# Evasion Weights (9 classes): tensor([0.3642, 0.5427, 0.7851, 0.9925, 1.0055, 2.6421, 3.2194, 4.1643, 4.8495],
#        device='cuda:0')
# loading xlnet-base-cased with 9 labels...
# pytorch_model.bin: 100% 467M/467M [00:02<00:00, 163MB/s]
#
# Epoch 1/15
# model.safetensors: 100% 467M/467M [00:04<00:00, 106MB/s]
#   Training Loss: 2.0445
#   >>> [Internal] Raw Evasion Performance (9 Classes):
#               precision    recall  f1-score   support
#
#            0       0.32      0.33      0.33        79
#            1       0.27      0.05      0.08        61
#            2       0.50      0.02      0.03        61
#            3       0.00      0.00      0.00        55
#            4       0.11      0.27      0.15        22
#            5       0.13      0.73      0.22        11
#            6       0.16      1.00      0.28         8
#            7       0.50      1.00      0.67         4
#            8       0.05      0.29      0.09         7
#
#     accuracy                           0.19       308
#    macro avg       0.23      0.41      0.20       308
# weighted avg       0.26      0.19      0.14       308
#
#   >>> [Target] Mapped Clarity Performance (Evasion -> Clarity):
#                  precision    recall  f1-score   support
#
#     Clear Reply       0.32      0.33      0.33        79
#      Ambivalent       0.71      0.37      0.49       206
# Clear Non-Reply       0.19      1.00      0.32        23
#
#        accuracy                           0.41       308
#       macro avg       0.41      0.57      0.38       308
#    weighted avg       0.57      0.41      0.43       308
#
#   [+] New Best Hierarchical Model (F1: 0.3774) -> Saving...
#
# Epoch 2/15
#   Training Loss: 1.7383
#   >>> [Internal] Raw Evasion Performance (9 Classes):
#               precision    recall  f1-score   support
#
#            0       0.73      0.10      0.18        79
#            1       0.55      0.10      0.17        61
#            2       0.24      0.54      0.33        61
#            3       0.29      0.18      0.22        55
#            4       0.08      0.23      0.11        22
#            5       0.46      0.55      0.50        11
#            6       0.27      1.00      0.42         8
#            7       1.00      1.00      1.00         4
#            8       0.00      0.00      0.00         7
#
#     accuracy                           0.26       308
#    macro avg       0.40      0.41      0.33       308
# weighted avg       0.43      0.26      0.23       308
#
#   >>> [Target] Mapped Clarity Performance (Evasion -> Clarity):
#                  precision    recall  f1-score   support
#
#     Clear Reply       0.73      0.10      0.18        79
#      Ambivalent       0.73      0.89      0.80       206
# Clear Non-Reply       0.43      0.87      0.57        23
#
#        accuracy                           0.69       308
#       macro avg       0.63      0.62      0.52       308
#    weighted avg       0.71      0.69      0.63       308
#
#   [+] New Best Hierarchical Model (F1: 0.5173) -> Saving...
#
# Epoch 3/15
#   Training Loss: 1.5214
#   >>> [Internal] Raw Evasion Performance (9 Classes):
#               precision    recall  f1-score   support
#
#            0       0.41      0.25      0.31        79
#            1       0.21      0.18      0.19        61
#            2       0.15      0.08      0.11        61
#            3       0.28      0.38      0.32        55
#            4       0.07      0.14      0.09        22
#            5       0.23      0.45      0.30        11
#            6       0.33      0.62      0.43         8
#            7       1.00      1.00      1.00         4
#            8       0.19      0.43      0.26         7
#
#     accuracy                           0.25       308
#    macro avg       0.32      0.39      0.34       308
# weighted avg       0.27      0.25      0.25       308
#
#   >>> [Target] Mapped Clarity Performance (Evasion -> Clarity):
#                  precision    recall  f1-score   support
#
#     Clear Reply       0.41      0.25      0.31        79
#      Ambivalent       0.73      0.77      0.75       206
# Clear Non-Reply       0.44      0.78      0.56        23
#
#        accuracy                           0.64       308
#       macro avg       0.53      0.60      0.54       308
#    weighted avg       0.63      0.64      0.62       308
#
#   [+] New Best Hierarchical Model (F1: 0.5417) -> Saving...
#
# Epoch 4/15
#   Training Loss: 1.2828
#   >>> [Internal] Raw Evasion Performance (9 Classes):
#               precision    recall  f1-score   support
#
#            0       0.50      0.14      0.22        79
#            1       0.30      0.05      0.08        61
#            2       0.23      0.85      0.37        61
#            3       0.23      0.05      0.09        55
#            4       0.00      0.00      0.00        22
#            5       0.42      0.45      0.43        11
#            6       0.45      0.62      0.53         8
#            7       0.33      1.00      0.50         4
#            8       0.00      0.00      0.00         7
#
#     accuracy                           0.27       308
#    macro avg       0.27      0.35      0.25       308
# weighted avg       0.31      0.27      0.20       308
#
#   >>> [Target] Mapped Clarity Performance (Evasion -> Clarity):
#                  precision    recall  f1-score   support
#
#     Clear Reply       0.50      0.14      0.22        79
#      Ambivalent       0.72      0.88      0.79       206
# Clear Non-Reply       0.46      0.70      0.55        23
#
#        accuracy                           0.68       308
#       macro avg       0.56      0.57      0.52       308
#    weighted avg       0.64      0.68      0.63       308
#
#
# Epoch 5/15
#   Training Loss: 1.0402
#   >>> [Internal] Raw Evasion Performance (9 Classes):
#               precision    recall  f1-score   support
#
#            0       0.33      0.73      0.45        79
#            1       0.27      0.15      0.19        61
#            2       0.45      0.08      0.14        61
#            3       0.31      0.16      0.21        55
#            4       0.22      0.18      0.20        22
#            5       0.29      0.45      0.36        11
#            6       0.36      0.62      0.45         8
#            7       1.00      1.00      1.00         4
#            8       0.00      0.00      0.00         7
#
#     accuracy                           0.32       308
#    macro avg       0.36      0.38      0.33       308
# weighted avg       0.33      0.32      0.27       308
#
#   >>> [Target] Mapped Clarity Performance (Evasion -> Clarity):
#                  precision    recall  f1-score   support
#
#     Clear Reply       0.33      0.73      0.45        79
#      Ambivalent       0.79      0.37      0.51       206
# Clear Non-Reply       0.46      0.70      0.55        23
#
#        accuracy                           0.49       308
#       macro avg       0.53      0.60      0.50       308
#    weighted avg       0.65      0.49      0.50       308
#
#
# Epoch 6/15
#   Training Loss: 0.8066
#   >>> [Internal] Raw Evasion Performance (9 Classes):
#               precision    recall  f1-score   support
#
#            0       0.41      0.37      0.39        79
#            1       0.26      0.15      0.19        61
#            2       0.38      0.18      0.24        61
#            3       0.22      0.55      0.32        55
#            4       0.00      0.00      0.00        22
#            5       0.50      0.45      0.48        11
#            6       0.40      1.00      0.57         8
#            7       0.80      1.00      0.89         4
#            8       0.00      0.00      0.00         7
#
#     accuracy                           0.31       308
#    macro avg       0.33      0.41      0.34       308
# weighted avg       0.31      0.31      0.29       308
#
#   >>> [Target] Mapped Clarity Performance (Evasion -> Clarity):
#                  precision    recall  f1-score   support
#
#     Clear Reply       0.41      0.37      0.39        79
#      Ambivalent       0.75      0.74      0.75       206
# Clear Non-Reply       0.51      0.78      0.62        23
#
#        accuracy                           0.65       308
#       macro avg       0.56      0.63      0.59       308
#    weighted avg       0.65      0.65      0.65       308
#
#   [+] New Best Hierarchical Model (F1: 0.5860) -> Saving...
#
# Epoch 7/15
#   Training Loss: 0.6045
#   >>> [Internal] Raw Evasion Performance (9 Classes):
#               precision    recall  f1-score   support
#
#            0       0.38      0.52      0.44        79
#            1       0.36      0.23      0.28        61
#            2       0.34      0.25      0.29        61
#            3       0.22      0.20      0.21        55
#            4       0.15      0.23      0.18        22
#            5       0.50      0.45      0.48        11
#            6       0.54      0.88      0.67         8
#            7       1.00      0.75      0.86         4
#            8       0.11      0.14      0.12         7
#
#     accuracy                           0.33       308
#    macro avg       0.40      0.40      0.39       308
# weighted avg       0.33      0.33      0.32       308
#
#   >>> [Target] Mapped Clarity Performance (Evasion -> Clarity):
#                  precision    recall  f1-score   support
#
#     Clear Reply       0.38      0.52      0.44        79
#      Ambivalent       0.78      0.67      0.72       206
# Clear Non-Reply       0.62      0.70      0.65        23
#
#        accuracy                           0.63       308
#       macro avg       0.59      0.63      0.60       308
#    weighted avg       0.67      0.63      0.64       308
#
#   [+] New Best Hierarchical Model (F1: 0.6044) -> Saving...
#
# Epoch 8/15
#   Training Loss: 0.4445
#   >>> [Internal] Raw Evasion Performance (9 Classes):
#               precision    recall  f1-score   support
#
#            0       0.45      0.32      0.37        79
#            1       0.45      0.16      0.24        61
#            2       0.32      0.52      0.40        61
#            3       0.26      0.35      0.30        55
#            4       0.16      0.14      0.15        22
#            5       0.45      0.45      0.45        11
#            6       0.40      1.00      0.57         8
#            7       1.00      1.00      1.00         4
#            8       0.00      0.00      0.00         7
#
#     accuracy                           0.34       308
#    macro avg       0.39      0.44      0.39       308
# weighted avg       0.37      0.34      0.33       308
#
#   >>> [Target] Mapped Clarity Performance (Evasion -> Clarity):
#                  precision    recall  f1-score   support
#
#     Clear Reply       0.45      0.32      0.37        79
#      Ambivalent       0.75      0.79      0.77       206
# Clear Non-Reply       0.51      0.78      0.62        23
#
#        accuracy                           0.67       308
#       macro avg       0.57      0.63      0.59       308
#    weighted avg       0.66      0.67      0.66       308
#
#
# Epoch 9/15
#   Training Loss: 0.3373
#   >>> [Internal] Raw Evasion Performance (9 Classes):
#               precision    recall  f1-score   support
#
#            0       0.42      0.35      0.39        79
#            1       0.29      0.11      0.16        61
#            2       0.33      0.46      0.39        61
#            3       0.24      0.25      0.25        55
#            4       0.11      0.23      0.15        22
#            5       0.45      0.45      0.45        11
#            6       0.47      0.88      0.61         8
#            7       1.00      0.75      0.86         4
#            8       0.00      0.00      0.00         7
#
#     accuracy                           0.31       308
#    macro avg       0.37      0.39      0.36       308
# weighted avg       0.32      0.31      0.31       308
#
#   >>> [Target] Mapped Clarity Performance (Evasion -> Clarity):
#                  precision    recall  f1-score   support
#
#     Clear Reply       0.42      0.35      0.39        79
#      Ambivalent       0.75      0.78      0.76       206
# Clear Non-Reply       0.55      0.70      0.62        23
#
#        accuracy                           0.66       308
#       macro avg       0.58      0.61      0.59       308
#    weighted avg       0.65      0.66      0.66       308
#
#
# Epoch 10/15
#   Training Loss: 0.2374
#   >>> [Internal] Raw Evasion Performance (9 Classes):
#               precision    recall  f1-score   support
#
#            0       0.39      0.58      0.47        79
#            1       0.32      0.16      0.22        61
#            2       0.32      0.41      0.36        61
#            3       0.24      0.15      0.18        55
#            4       0.11      0.09      0.10        22
#            5       0.36      0.45      0.40        11
#            6       0.50      0.62      0.56         8
#            7       1.00      1.00      1.00         4
#            8       0.00      0.00      0.00         7
#
#     accuracy                           0.34       308
#    macro avg       0.36      0.39      0.36       308
# weighted avg       0.32      0.34      0.32       308
#
#   >>> [Target] Mapped Clarity Performance (Evasion -> Clarity):
#                  precision    recall  f1-score   support
#
#     Clear Reply       0.39      0.58      0.47        79
#      Ambivalent       0.77      0.61      0.68       206
# Clear Non-Reply       0.50      0.61      0.55        23
#
#        accuracy                           0.60       308
#       macro avg       0.55      0.60      0.57       308
#    weighted avg       0.65      0.60      0.62       308
#
#
# Epoch 11/15
#   Training Loss: 0.1673
#   >>> [Internal] Raw Evasion Performance (9 Classes):
#               precision    recall  f1-score   support
#
#            0       0.38      0.63      0.48        79
#            1       0.31      0.30      0.30        61
#            2       0.41      0.26      0.32        61
#            3       0.25      0.16      0.20        55
#            4       0.08      0.05      0.06        22
#            5       0.45      0.45      0.45        11
#            6       0.50      0.88      0.64         8
#            7       0.75      0.75      0.75         4
#            8       0.00      0.00      0.00         7
#
#     accuracy                           0.35       308
#    macro avg       0.35      0.39      0.35       308
# weighted avg       0.33      0.35      0.33       308
#
#   >>> [Target] Mapped Clarity Performance (Evasion -> Clarity):
#                  precision    recall  f1-score   support
#
#     Clear Reply       0.38      0.63      0.48        79
#      Ambivalent       0.80      0.57      0.67       206
# Clear Non-Reply       0.55      0.70      0.62        23
#
#        accuracy                           0.60       308
#       macro avg       0.58      0.63      0.59       308
#    weighted avg       0.67      0.60      0.61       308
#
#
# Epoch 12/15
#   Training Loss: 0.1301
#   >>> [Internal] Raw Evasion Performance (9 Classes):
#               precision    recall  f1-score   support
#
#            0       0.37      0.59      0.45        79
#            1       0.33      0.23      0.27        61
#            2       0.39      0.26      0.31        61
#            3       0.25      0.25      0.25        55
#            4       0.18      0.09      0.12        22
#            5       0.45      0.45      0.45        11
#            6       0.50      0.88      0.64         8
#            7       1.00      1.00      1.00         4
#            8       0.00      0.00      0.00         7
#
#     accuracy                           0.35       308
#    macro avg       0.39      0.42      0.39       308
# weighted avg       0.34      0.35      0.33       308
#
#   >>> [Target] Mapped Clarity Performance (Evasion -> Clarity):
#                  precision    recall  f1-score   support
#
#     Clear Reply       0.37      0.59      0.45        79
#      Ambivalent       0.79      0.58      0.67       206
# Clear Non-Reply       0.59      0.74      0.65        23
#
#        accuracy                           0.59       308
#       macro avg       0.58      0.64      0.59       308
#    weighted avg       0.67      0.59      0.61       308
#
#
# Epoch 13/15
#   Training Loss: 0.1061
#   >>> [Internal] Raw Evasion Performance (9 Classes):
#               precision    recall  f1-score   support
#
#            0       0.38      0.66      0.48        79
#            1       0.41      0.25      0.31        61
#            2       0.44      0.39      0.41        61
#            3       0.29      0.20      0.24        55
#            4       0.00      0.00      0.00        22
#            5       0.45      0.45      0.45        11
#            6       0.46      0.75      0.57         8
#            7       1.00      1.00      1.00         4
#            8       0.00      0.00      0.00         7
#
#     accuracy                           0.38       308
#    macro avg       0.38      0.41      0.39       308
# weighted avg       0.36      0.38      0.35       308
#
#   >>> [Target] Mapped Clarity Performance (Evasion -> Clarity):
#                  precision    recall  f1-score   support
#
#     Clear Reply       0.38      0.66      0.48        79
#      Ambivalent       0.81      0.57      0.67       206
# Clear Non-Reply       0.57      0.70      0.63        23
#
#        accuracy                           0.60       308
#       macro avg       0.59      0.64      0.59       308
#    weighted avg       0.68      0.60      0.62       308
#
#
# Epoch 14/15
#   Training Loss: 0.0807
#   >>> [Internal] Raw Evasion Performance (9 Classes):
#               precision    recall  f1-score   support
#
#            0       0.40      0.62      0.49        79
#            1       0.32      0.25      0.28        61
#            2       0.42      0.30      0.35        61
#            3       0.24      0.22      0.23        55
#            4       0.12      0.09      0.11        22
#            5       0.50      0.45      0.48        11
#            6       0.50      0.88      0.64         8
#            7       1.00      1.00      1.00         4
#            8       0.00      0.00      0.00         7
#
#     accuracy                           0.36       308
#    macro avg       0.39      0.42      0.40       308
# weighted avg       0.34      0.36      0.34       308
#
#   >>> [Target] Mapped Clarity Performance (Evasion -> Clarity):
#                  precision    recall  f1-score   support
#
#     Clear Reply       0.40      0.62      0.49        79
#      Ambivalent       0.81      0.62      0.70       206
# Clear Non-Reply       0.61      0.74      0.67        23
#
#        accuracy                           0.63       308
#       macro avg       0.60      0.66      0.62       308
#    weighted avg       0.69      0.63      0.64       308
#
#   [+] New Best Hierarchical Model (F1: 0.6172) -> Saving...
#
# Epoch 15/15
#   Training Loss: 0.0734
#   >>> [Internal] Raw Evasion Performance (9 Classes):
#               precision    recall  f1-score   support
#
#            0       0.40      0.65      0.49        79
#            1       0.30      0.25      0.27        61
#            2       0.47      0.33      0.38        61
#            3       0.24      0.18      0.21        55
#            4       0.13      0.09      0.11        22
#            5       0.42      0.45      0.43        11
#            6       0.46      0.75      0.57         8
#            7       1.00      1.00      1.00         4
#            8       0.00      0.00      0.00         7
#
#     accuracy                           0.37       308
#    macro avg       0.38      0.41      0.39       308
# weighted avg       0.35      0.37      0.34       308
#
#   >>> [Target] Mapped Clarity Performance (Evasion -> Clarity):
#                  precision    recall  f1-score   support
#
#     Clear Reply       0.40      0.65      0.49        79
#      Ambivalent       0.81      0.60      0.69       206
# Clear Non-Reply       0.55      0.70      0.62        23
#
#        accuracy                           0.62       308
#       macro avg       0.59      0.65      0.60       308
#    weighted avg       0.69      0.62      0.63       308
#
#
# Done. Best Mapped Clarity F1 (k=9): 0.6172

# %%
print("Start Experiment 3: Reduced Training (k=5)...")
# !python -m src.train_reduced
# Out:
# Start Experiment 3: Reduced Training (k=5)...
# 2025-12-24 16:08:18.152024: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766592498.171665    1597 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766592498.177578    1597 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1766592498.192575    1597 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766592498.192605    1597 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766592498.192608    1597 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1766592498.192612    1597 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-12-24 16:08:18.197070: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# === STARTING REDUCED TRAINING (k=5) ===
# spiece.model: 100% 798k/798k [00:00<00:00, 20.7MB/s]
# tokenizer.json: 100% 1.38M/1.38M [00:00<00:00, 7.28MB/s]
# config.json: 100% 760/760 [00:00<00:00, 5.41MB/s]
# --- Loading Datasets (Mode: evasion_5) ---
# Applying Democratic Voting Logic...
# Train size: 3448 | Test size: 308
# Reduced Evasion Weights (5 classes): tensor([0.6555, 0.6344, 0.7236, 2.6121, 7.4957], device='cuda:0')
# loading xlnet-base-cased with 5 labels...
# pytorch_model.bin: 100% 467M/467M [00:03<00:00, 121MB/s]
#
# Epoch 1/15
# model.safetensors: 100% 467M/467M [00:03<00:00, 135MB/s]
#   Training Loss: 1.4729
#   >>> [Internal] Reduced Evasion Performance (5 Classes):
#               precision    recall  f1-score   support
#
#            0       0.67      0.03      0.05        79
#            1       0.28      0.70      0.40        83
#            2       0.55      0.26      0.35       123
#            3       0.53      0.53      0.53        19
#            4       0.17      1.00      0.30         4
#
#     accuracy                           0.34       308
#    macro avg       0.44      0.50      0.33       308
# weighted avg       0.50      0.34      0.30       308
#
#   >>> [Target] Mapped Clarity Performance (Reduced Evasion -> Clarity):
#                  precision    recall  f1-score   support
#
#     Clear Reply       0.67      0.03      0.05        79
#      Ambivalent       0.71      0.91      0.80       206
# Clear Non-Reply       0.33      0.61      0.43        23
#
#        accuracy                           0.66       308
#       macro avg       0.57      0.51      0.43       308
#    weighted avg       0.67      0.66      0.58       308
#
#   [+] New Best Reduced Model (F1: 0.4257) -> Saving...
#
# Epoch 2/15
#   Training Loss: 1.1814
#   >>> [Internal] Reduced Evasion Performance (5 Classes):
#               precision    recall  f1-score   support
#
#            0       0.52      0.18      0.26        79
#            1       0.60      0.07      0.13        83
#            2       0.47      0.87      0.61       123
#            3       0.30      0.58      0.39        19
#            4       1.00      1.00      1.00         4
#
#     accuracy                           0.46       308
#    macro avg       0.58      0.54      0.48       308
# weighted avg       0.51      0.46      0.38       308
#
#   >>> [Target] Mapped Clarity Performance (Reduced Evasion -> Clarity):
#                  precision    recall  f1-score   support
#
#     Clear Reply       0.52      0.18      0.26        79
#      Ambivalent       0.72      0.84      0.78       206
# Clear Non-Reply       0.37      0.65      0.47        23
#
#        accuracy                           0.66       308
#       macro avg       0.54      0.56      0.50       308
#    weighted avg       0.65      0.66      0.62       308
#
#   [+] New Best Reduced Model (F1: 0.5044) -> Saving...
#
# Epoch 3/15
#   Training Loss: 0.9873
#   >>> [Internal] Reduced Evasion Performance (5 Classes):
#               precision    recall  f1-score   support
#
#            0       0.51      0.25      0.34        79
#            1       0.31      0.43      0.36        83
#            2       0.49      0.37      0.42       123
#            3       0.28      0.84      0.42        19
#            4       0.80      1.00      0.89         4
#
#     accuracy                           0.39       308
#    macro avg       0.48      0.58      0.49       308
# weighted avg       0.44      0.39      0.39       308
#
#   >>> [Target] Mapped Clarity Performance (Reduced Evasion -> Clarity):
#                  precision    recall  f1-score   support
#
#     Clear Reply       0.51      0.25      0.34        79
#      Ambivalent       0.74      0.75      0.75       206
# Clear Non-Reply       0.32      0.87      0.47        23
#
#        accuracy                           0.63       308
#       macro avg       0.53      0.62      0.52       308
#    weighted avg       0.65      0.63      0.62       308
#
#   [+] New Best Reduced Model (F1: 0.5184) -> Saving...
#
# Epoch 4/15
#   Training Loss: 0.8494
#   >>> [Internal] Reduced Evasion Performance (5 Classes):
#               precision    recall  f1-score   support
#
#            0       0.44      0.29      0.35        79
#            1       0.56      0.12      0.20        83
#            2       0.46      0.82      0.59       123
#            3       0.73      0.42      0.53        19
#            4       0.67      1.00      0.80         4
#
#     accuracy                           0.47       308
#    macro avg       0.57      0.53      0.49       308
# weighted avg       0.50      0.47      0.42       308
#
#   >>> [Target] Mapped Clarity Performance (Reduced Evasion -> Clarity):
#                  precision    recall  f1-score   support
#
#     Clear Reply       0.44      0.29      0.35        79
#      Ambivalent       0.72      0.84      0.78       206
# Clear Non-Reply       0.71      0.52      0.60        23
#
#        accuracy                           0.68       308
#       macro avg       0.62      0.55      0.58       308
#    weighted avg       0.65      0.68      0.65       308
#
#   [+] New Best Reduced Model (F1: 0.5762) -> Saving...
#
# Epoch 5/15
#   Training Loss: 0.7165
#   >>> [Internal] Reduced Evasion Performance (5 Classes):
#               precision    recall  f1-score   support
#
#            0       0.51      0.27      0.35        79
#            1       0.32      0.40      0.36        83
#            2       0.50      0.47      0.49       123
#            3       0.30      0.68      0.41        19
#            4       0.80      1.00      0.89         4
#
#     accuracy                           0.42       308
#    macro avg       0.49      0.56      0.50       308
# weighted avg       0.45      0.42      0.42       308
#
#   >>> [Target] Mapped Clarity Performance (Reduced Evasion -> Clarity):
#                  precision    recall  f1-score   support
#
#     Clear Reply       0.51      0.27      0.35        79
#      Ambivalent       0.73      0.78      0.75       206
# Clear Non-Reply       0.35      0.74      0.47        23
#
#        accuracy                           0.64       308
#       macro avg       0.53      0.59      0.53       308
#    weighted avg       0.65      0.64      0.63       308
#
#
# Epoch 6/15
#   Training Loss: 0.5816
#   >>> [Internal] Reduced Evasion Performance (5 Classes):
#               precision    recall  f1-score   support
#
#            0       0.47      0.56      0.51        79
#            1       0.42      0.13      0.20        83
#            2       0.47      0.58      0.52       123
#            3       0.32      0.58      0.42        19
#            4       0.75      0.75      0.75         4
#
#     accuracy                           0.45       308
#    macro avg       0.49      0.52      0.48       308
# weighted avg       0.45      0.45      0.43       308
#
#   >>> [Target] Mapped Clarity Performance (Reduced Evasion -> Clarity):
#                  precision    recall  f1-score   support
#
#     Clear Reply       0.47      0.56      0.51        79
#      Ambivalent       0.77      0.66      0.71       206
# Clear Non-Reply       0.37      0.61      0.46        23
#
#        accuracy                           0.63       308
#       macro avg       0.53      0.61      0.56       308
#    weighted avg       0.66      0.63      0.64       308
#
#
# Epoch 7/15
#   Training Loss: 0.4560
#   >>> [Internal] Reduced Evasion Performance (5 Classes):
#               precision    recall  f1-score   support
#
#            0       0.39      0.66      0.49        79
#            1       0.46      0.13      0.21        83
#            2       0.50      0.42      0.46       123
#            3       0.29      0.63      0.40        19
#            4       0.67      1.00      0.80         4
#
#     accuracy                           0.43       308
#    macro avg       0.46      0.57      0.47       308
# weighted avg       0.45      0.43      0.40       308
#
#   >>> [Target] Mapped Clarity Performance (Reduced Evasion -> Clarity):
#                  precision    recall  f1-score   support
#
#     Clear Reply       0.39      0.66      0.49        79
#      Ambivalent       0.77      0.48      0.59       206
# Clear Non-Reply       0.34      0.70      0.46        23
#
#        accuracy                           0.54       308
#       macro avg       0.50      0.61      0.51       308
#    weighted avg       0.64      0.54      0.55       308
#
#
# Epoch 8/15
#   Training Loss: 0.3528
#   >>> [Internal] Reduced Evasion Performance (5 Classes):
#               precision    recall  f1-score   support
#
#            0       0.43      0.67      0.52        79
#            1       0.41      0.42      0.41        83
#            2       0.52      0.32      0.39       123
#            3       0.39      0.37      0.38        19
#            4       0.80      1.00      0.89         4
#
#     accuracy                           0.45       308
#    macro avg       0.51      0.56      0.52       308
# weighted avg       0.46      0.45      0.44       308
#
#   >>> [Target] Mapped Clarity Performance (Reduced Evasion -> Clarity):
#                  precision    recall  f1-score   support
#
#     Clear Reply       0.43      0.67      0.52        79
#      Ambivalent       0.80      0.63      0.70       206
# Clear Non-Reply       0.48      0.48      0.48        23
#
#        accuracy                           0.63       308
#       macro avg       0.57      0.59      0.57       308
#    weighted avg       0.68      0.63      0.64       308
#
#
# Epoch 9/15
#   Training Loss: 0.2522
#   >>> [Internal] Reduced Evasion Performance (5 Classes):
#               precision    recall  f1-score   support
#
#            0       0.49      0.51      0.50        79
#            1       0.34      0.47      0.40        83
#            2       0.41      0.27      0.33       123
#            3       0.43      0.63      0.51        19
#            4       0.80      1.00      0.89         4
#
#     accuracy                           0.42       308
#    macro avg       0.50      0.58      0.52       308
# weighted avg       0.42      0.42      0.41       308
#
#   >>> [Target] Mapped Clarity Performance (Reduced Evasion -> Clarity):
#                  precision    recall  f1-score   support
#
#     Clear Reply       0.49      0.51      0.50        79
#      Ambivalent       0.77      0.73      0.75       206
# Clear Non-Reply       0.48      0.70      0.57        23
#
#        accuracy                           0.67       308
#       macro avg       0.58      0.64      0.61       308
#    weighted avg       0.68      0.67      0.67       308
#
#   [+] New Best Reduced Model (F1: 0.6071) -> Saving...
#
# Epoch 10/15
#   Training Loss: 0.1758
#   >>> [Internal] Reduced Evasion Performance (5 Classes):
#               precision    recall  f1-score   support
#
#            0       0.42      0.62      0.50        79
#            1       0.46      0.33      0.38        83
#            2       0.49      0.41      0.44       123
#            3       0.42      0.53      0.47        19
#            4       0.80      1.00      0.89         4
#
#     accuracy                           0.45       308
#    macro avg       0.52      0.58      0.54       308
# weighted avg       0.46      0.45      0.45       308
#
#   >>> [Target] Mapped Clarity Performance (Reduced Evasion -> Clarity):
#                  precision    recall  f1-score   support
#
#     Clear Reply       0.42      0.62      0.50        79
#      Ambivalent       0.78      0.61      0.69       206
# Clear Non-Reply       0.48      0.61      0.54        23
#
#        accuracy                           0.61       308
#       macro avg       0.56      0.61      0.57       308
#    weighted avg       0.67      0.61      0.63       308
#
#
# Epoch 11/15
#   Training Loss: 0.1386
#   >>> [Internal] Reduced Evasion Performance (5 Classes):
#               precision    recall  f1-score   support
#
#            0       0.51      0.56      0.53        79
#            1       0.35      0.43      0.39        83
#            2       0.49      0.30      0.37       123
#            3       0.38      0.74      0.50        19
#            4       0.80      1.00      0.89         4
#
#     accuracy                           0.44       308
#    macro avg       0.50      0.61      0.54       308
# weighted avg       0.45      0.44      0.43       308
#
#   >>> [Target] Mapped Clarity Performance (Reduced Evasion -> Clarity):
#                  precision    recall  f1-score   support
#
#     Clear Reply       0.51      0.56      0.53        79
#      Ambivalent       0.79      0.69      0.74       206
# Clear Non-Reply       0.43      0.78      0.55        23
#
#        accuracy                           0.66       308
#       macro avg       0.58      0.68      0.61       308
#    weighted avg       0.69      0.66      0.67       308
#
#   [+] New Best Reduced Model (F1: 0.6076) -> Saving...
#
# Epoch 12/15
#   Training Loss: 0.0923
#   >>> [Internal] Reduced Evasion Performance (5 Classes):
#               precision    recall  f1-score   support
#
#            0       0.40      0.62      0.49        79
#            1       0.38      0.23      0.29        83
#            2       0.48      0.38      0.43       123
#            3       0.37      0.68      0.48        19
#            4       0.80      1.00      0.89         4
#
#     accuracy                           0.43       308
#    macro avg       0.49      0.58      0.51       308
# weighted avg       0.43      0.43      0.41       308
#
#   >>> [Target] Mapped Clarity Performance (Reduced Evasion -> Clarity):
#                  precision    recall  f1-score   support
#
#     Clear Reply       0.40      0.62      0.49        79
#      Ambivalent       0.78      0.55      0.65       206
# Clear Non-Reply       0.42      0.74      0.54        23
#
#        accuracy                           0.58       308
#       macro avg       0.54      0.64      0.56       308
#    weighted avg       0.65      0.58      0.60       308
#
#
# Epoch 13/15
#   Training Loss: 0.0800
#   >>> [Internal] Reduced Evasion Performance (5 Classes):
#               precision    recall  f1-score   support
#
#            0       0.46      0.63      0.53        79
#            1       0.38      0.36      0.37        83
#            2       0.49      0.34      0.40       123
#            3       0.43      0.68      0.53        19
#            4       0.80      1.00      0.89         4
#
#     accuracy                           0.45       308
#    macro avg       0.51      0.60      0.55       308
# weighted avg       0.45      0.45      0.44       308
#
#   >>> [Target] Mapped Clarity Performance (Reduced Evasion -> Clarity):
#                  precision    recall  f1-score   support
#
#     Clear Reply       0.46      0.63      0.53        79
#      Ambivalent       0.80      0.64      0.71       206
# Clear Non-Reply       0.49      0.74      0.59        23
#
#        accuracy                           0.64       308
#       macro avg       0.58      0.67      0.61       308
#    weighted avg       0.69      0.64      0.65       308
#
#   [+] New Best Reduced Model (F1: 0.6087) -> Saving...
#
# Epoch 14/15
#   Training Loss: 0.0605
#   >>> [Internal] Reduced Evasion Performance (5 Classes):
#               precision    recall  f1-score   support
#
#            0       0.40      0.66      0.50        79
#            1       0.40      0.29      0.34        83
#            2       0.48      0.34      0.40       123
#            3       0.44      0.58      0.50        19
#            4       0.80      1.00      0.89         4
#
#     accuracy                           0.43       308
#    macro avg       0.50      0.57      0.52       308
# weighted avg       0.44      0.43      0.42       308
#
#   >>> [Target] Mapped Clarity Performance (Reduced Evasion -> Clarity):
#                  precision    recall  f1-score   support
#
#     Clear Reply       0.40      0.66      0.50        79
#      Ambivalent       0.78      0.56      0.66       206
# Clear Non-Reply       0.50      0.65      0.57        23
#
#        accuracy                           0.59       308
#       macro avg       0.56      0.62      0.57       308
#    weighted avg       0.66      0.59      0.61       308
#
#
# Epoch 15/15
