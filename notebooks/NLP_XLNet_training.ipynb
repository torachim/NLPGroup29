# %%
from google.colab import drive
import os

# connect to drive
drive.mount('/content/drive')

# change to project folder
project_path = '/content/drive/MyDrive/NLPGroup29'

try:
    os.chdir(project_path)
    print(f"Erfolgreich in Ordner gewechselt: {os.getcwd()}")
except FileNotFoundError:
    print("Fehler: Ordner nicht gefunden! Bitte Pfad prüfen.")

# download requirements
print("Installiere Bibliotheken...")
# !pip install -r requirements.txt
# Out:
# Mounted at /content/drive
# Erfolgreich in Ordner gewechselt: /content/drive/MyDrive/NLPGroup29
# Installiere Bibliotheken...
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 30.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.1/345.1 kB 18.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.9/114.9 kB 11.0 MB/s eta 0:00:00
# ...

# %%
print("Start experiment 1: Direct Clarity Training...")
# !python -m src.train_direct
# Out:
# Start experiment 1: Direct Clarity Training...
# 2025-12-23 14:38:28.571743: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766500708.604967     967 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766500708.611825     967 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1766500708.628853     967 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
print("Start Experiment 2: Hierarchical Training (k=9)...")
# !python -m src.train_hierarchical
# Out:
# Start Experiment 2: Hierarchical Training (k=9)...
# 2025-12-23 16:36:14.845357: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766507774.871646   29969 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766507774.878436   29969 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1766507774.896137   29969 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
print("Start Experiment 3: Reduced Training (k=5)...")
# !python -m src.train_reduced
# Out:
# Start Experiment 3: Reduced Training (k=5)...
# 2025-12-23 21:02:02.394783: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766523722.426555    1399 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766523722.436355    1399 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1766523722.460394    1399 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
